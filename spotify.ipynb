# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv("tracks.csv")
# To display the top 5 rows
df.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   1922-02-22         0.645  0.4450    0   -13.338   1.0       0.4510
# 1   1922-06-01         0.695  0.2630    0   -22.136   1.0       0.9570
# 2   1922-03-21         0.434  0.1770    1   -21.180   1.0       0.0512
# 3   1922-03-21         0.321  0.0946    7   -27.961   1.0       0.0504
# 4         1922         0.402  0.1580    3   -16.900   0.0       0.0390
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674            0.7440     0.151    0.127  104.851             3.0
# 1         0.797            0.0000     0.148    0.655  102.009             1.0
# 2         0.994            0.0218     0.212    0.457  130.418             5.0
# 3         0.995            0.9180     0.104    0.397  169.980             3.0
# 4         0.989            0.1300     0.311    0.196  103.220             4.0

# %%
df.tail(5)
# Out:
#                            id  \
# 15097  0T85LvqNvl47ji8TA8fXvH
# 15098  0TAtRfjN3VV86Legl1Up2u
# 15099  0U8dZOTnSlJN6atbQfYwo2
# 15100  0UWPTatCUtptbl2FcGN1M3
# 15101  0Ucg9kuPZeM6BShzBJzYYH
#
#                                                     name  popularity  \
# 15097  Mélodies (2006 Digital Remaster), Le Promenoir...           0
# 15098                      Bhoolana Na Yaad Karo Na Karo           0
# 15099                             Her Akşam Gün Batarken           0
# 15100        Goldberg Variations, BWV 988: Variation VII           0
# 15101  Don Giovanni, K. 527: Ich weiß ein Mittel - Su...           0
#
#        duration_ms  explicit  \
# 15097       225044         0
# 15098       166920         0
# 15099       194876         0
# 15100        97600         0
# 15101       172365         0
#
#                                                  artists  \
# 15097  ['Claude Debussy', 'Roger Desormière/Choeurs Y...
# 15098                ['Snehprabha Pradhan', 'Ishwarlal']
# 15099          ['Ibrahim Özgür', 'Park Otel Orkestrası']
# 15100         ['Johann Sebastian Bach', 'Claudio Arrau']
# 15101  ['Wolfgang Amadeus Mozart', 'Maria Cebotari', ...
#
#                                               id_artists release_date  \
# 15097  ['1Uff91EOsvd99rtAupatMP', '3ahkASqzOZFIrXLlwt...         1941
# 15098  ['5bQFhFUCi9ZDwAA9jmqXc7', '0zww9oJFmauslELTBf...   1941-01-01
# 15099  ['6BZBUpw0VypOZh9PngBob1', '66onaPb8N5eZPj8kkL...   1941-01-01
# 15100  ['5aIqB5nVVvmFsvSdExz408', '5k15M5itLxlNtLk7BG...         1941
# 15101  ['4NJhFmfw43RLBLjQvxDuRS', '5v8LSlCKBZg04bWp2D...   1941-01-01
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 15097         0.260  0.0612    2   -25.768   1.0       0.0430         0.983
# 15098         0.467  0.1100   10   -20.571   1.0       0.0492         0.995
# 15099         0.595  0.1420   11   -15.769   0.0       0.0766         0.996
# 15100         0.686  0.1140    7   -22.548   1.0       0.0464         0.995
# 15101         0.455  0.0642    0   -18.042   NaN          NaN           NaN
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 15097          0.000004     0.178   0.0527   86.602             4.0
# 15098          0.968000     0.214   0.6670  119.556             4.0
# 15099          0.783000     0.103   0.5570  118.792             4.0
# 15100          0.887000     0.164   0.9210   80.388             4.0
# 15101               NaN       NaN      NaN      NaN             NaN

# %%
df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature      float64
# dtype: object

# %% [markdown]
# # New Section

# %%
df = df.drop(['duration_ms', 'liveness', 'tempo', 'time_signature', 'instrumentalness'], axis=1)
df.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.645  0.4450    0   -13.338   1.0       0.4510         0.674
# 1         0.695  0.2630    0   -22.136   1.0       0.9570         0.797
# 2         0.434  0.1770    1   -21.180   1.0       0.0512         0.994
# 3         0.321  0.0946    7   -27.961   1.0       0.0504         0.995
# 4         0.402  0.1580    3   -16.900   0.0       0.0390         0.989
#
#    valence
# 0    0.127
# 1    0.655
# 2    0.457
# 3    0.397
# 4    0.196

# %%
df.shape
# Out:
# (15102, 15)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 15)

# %%
df.count()
# Out:
# id              15102
# name            15102
# popularity      15102
# explicit        15102
# artists         15102
# id_artists      15102
# release_date    15102
# danceability    15102
# energy          15102
# key             15102
# loudness        15102
# mode            15101
# speechiness     15101
# acousticness    15101
# valence         15101
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    explicit              artists                  id_artists release_date  \
# 0         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']         1922
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.645  0.4450    0   -13.338   1.0       0.4510         0.674
# 1         0.695  0.2630    0   -22.136   1.0       0.9570         0.797
# 2         0.434  0.1770    1   -21.180   1.0       0.0512         0.994
# 3         0.321  0.0946    7   -27.961   1.0       0.0504         0.995
# 4         0.402  0.1580    3   -16.900   0.0       0.0390         0.989
#
#    valence
# 0    0.127
# 1    0.655
# 2    0.457
# 3    0.397
# 4    0.196

# %%
df.count()
# Out:
# id              15102
# name            15102
# popularity      15102
# explicit        15102
# artists         15102
# id_artists      15102
# release_date    15102
# danceability    15102
# energy          15102
# key             15102
# loudness        15102
# mode            15101
# speechiness     15101
# acousticness    15101
# valence         15101
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# id              0
# name            0
# popularity      0
# explicit        0
# artists         0
# id_artists      0
# release_date    0
# danceability    0
# energy          0
# key             0
# loudness        0
# mode            1
# speechiness     1
# acousticness    1
# valence         1
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# id              15101
# name            15101
# popularity      15101
# explicit        15101
# artists         15101
# id_artists      15101
# release_date    15101
# danceability    15101
# energy          15101
# key             15101
# loudness        15101
# mode            15101
# speechiness     15101
# acousticness    15101
# valence         15101
# dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# id              0
# name            0
# popularity      0
# explicit        0
# artists         0
# id_artists      0
# release_date    0
# danceability    0
# energy          0
# key             0
# loudness        0
# mode            0
# speechiness     0
# acousticness    0
# valence         0
# dtype: int64

# %%
sns.boxplot(x=df['popularity'])
# Out:
# <Axes: xlabel='popularity'>

# %%
sns.boxplot(x=df['energy'])
# Out:
# <Axes: xlabel='energy'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# popularity      1.0000
# explicit        0.0000
# danceability    0.2480
# energy          0.1800
# key             6.0000
# loudness        7.8180
# mode            1.0000
# speechiness     0.1929
# acousticness    0.1590
# valence         0.3610
# dtype: float64
# <ipython-input-21-d7397e803310>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-21-d7397e803310>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# <ipython-input-22-f4e1682787c4>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (8521, 15)

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-30-a44b43776930>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#               popularity  explicit  danceability    energy       key  \
# popularity      1.000000       NaN      0.041880  0.032006 -0.000201
# explicit             NaN       NaN           NaN       NaN       NaN
# danceability    0.041880       NaN      1.000000  0.155484 -0.016163
# energy          0.032006       NaN      0.155484  1.000000 -0.008715
# key            -0.000201       NaN     -0.016163 -0.008715  1.000000
# loudness        0.051287       NaN      0.273666  0.686189 -0.020841
# mode            0.001727       NaN      0.046689 -0.010979 -0.039781
# speechiness    -0.030995       NaN      0.356733  0.010664  0.013573
# acousticness   -0.081664       NaN      0.041163 -0.236466  0.019159
# valence         0.018785       NaN      0.674626  0.449769  0.015973
#
#               loudness      mode  speechiness  acousticness   valence
# popularity    0.051287  0.001727    -0.030995     -0.081664  0.018785
# explicit           NaN       NaN          NaN           NaN       NaN
# danceability  0.273666  0.046689     0.356733      0.041163  0.674626
# energy        0.686189 -0.010979     0.010664     -0.236466  0.449769
# key          -0.020841 -0.039781     0.013573      0.019159  0.015973
# loudness      1.000000  0.035438    -0.009161     -0.144770  0.353184
# mode          0.035438  1.000000     0.016767     -0.022019  0.051714
# speechiness  -0.009161  0.016767     1.000000      0.054373  0.263222
# acousticness -0.144770 -0.022019     0.054373      1.000000  0.036650
# valence       0.353184  0.051714     0.263222      0.036650  1.000000
